# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import numpy as np

# %%
x = ["10%", "40%", "70%"]
# ctd
y_ctd_s = [
    [2.60, 7.28, 7.63],
    [5.14,7.55,7.54],
    [6.51,7.94,8.25],
    [6.85,8.87,9.41]
]

y_ctd_a = [
    [1.22, 3.21, 3.66],
    [2.25,3.56,3.74],
    [2.31,4.16,4.83],
    [3.13,5.12,5.27]
]

y_ctd_t = [
    [0.83,2.35,2.28],
    [0.85,2.09,2.10],
    [1.65,3.24,3.54],
    [2.41,3.78,3.78]
]

y_ctd_b = [
    [1.02,2.81,2.95],
    [1.33,2.38,2.75],
    [1.76,3.02,3.70],
    [2.52,4.15,4.36]
]

# csd
# y_ctd_s = [
#     [0.26,1.02,2.44],
#     [2.37,2.90,5.03],
#     [6.51,7.9],
#     [6.85,8.87,9.41]
# ]

# y_ctd_a = [
#     [1.22, 3.21, 3.66],
#     [2.25,3.56,3.74],
#     [2.31,4.16,4.83],
#     [3.13,5.12,5.27]
# ]

# y_ctd_t = [
#     [0.83,2.35,2.28],
#     [0.85,2.09,2.10],
#     [1.65,3.24,3.54],
#     [2.41,3.78,3.78]
# ]

# y_ctd_b = [
#     [1.02,2.81,2.95],
#     [1.33,2.38,2.75],
#     [1.76,3.02,3.70],
#     [2.52,4.15,4.36]
# ]


figure(figsize=(20, 4))

ax1 = plt.subplot(141)

ax1.plot(x, y_ctd_s[0], 'o-', label='None')
ax1.plot(x, y_ctd_s[1], 'o-', label='Synthesized-Midi')
ax1.plot(x, y_ctd_s[2], 'o-', label='Standard-Vocal')
ax1.plot(x, y_ctd_s[3], 'o-', label='Expressive-Vocal')
ax1.legend()
ax1.set_title('Median-SDR-Soprano-Cantoria Dataset')

ax2 = plt.subplot(142)

ax2.plot(x, y_ctd_a[0], 'o-', label='None')
ax2.plot(x, y_ctd_a[1], 'o-', label='Synthesized-Midi')
ax2.plot(x, y_ctd_a[2], 'o-', label='Standard-Vocal')
ax2.plot(x, y_ctd_a[3], 'o-', label='Expressive-Vocal')
ax2.legend()
ax2.set_title('Median-SDR-Alto-Cantoria Dataset')

ax3 = plt.subplot(143)

ax3.plot(x, y_ctd_t[0], 'o-', label='None')
ax3.plot(x, y_ctd_t[1], 'o-', label='Synthesized-Midi')
ax3.plot(x, y_ctd_t[2], 'o-', label='Standard-Vocal')
ax3.plot(x, y_ctd_t[3], 'o-', label='Expressive-Vocal')
ax3.legend()
ax3.set_title('Median-SDR-Tenor-Cantoria Dataset')

ax4 = plt.subplot(144)

ax4.plot(x, y_ctd_b[0], 'o-', label='None')
ax4.plot(x, y_ctd_b[1], 'o-', label='Synthesized-Midi')
ax4.plot(x, y_ctd_b[2], 'o-', label='Standard-Vocal')
ax4.plot(x, y_ctd_b[3], 'o-', label='Expressive-Vocal')
ax4.legend()
ax4.set_title('Median-SDR-Bass-Cantoria Dataset')

plt.show()
