# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import numpy as np

# %%
x = ["10%", "40%", "70%"]
# ctd
# y_ctd_s = [
#     [2.60, 7.28, 7.63],
#     [5.14,7.55,7.54],
#     [6.51,7.94,8.25],
#     [6.85,8.87,9.41]
# ]

# y_ctd_a = [
#     [1.22, 3.54, 3.66],
#     [1.89,3.56,3.74],
#     [2.31,4.16,4.83],
#     [3.13,5.12,5.27]
# ]

# y_ctd_t = [
#     [0.54,2.35,2.28],
#     [0.45,2.09,2.10],
#     [1.00,3.24,3.54],
#     [2.01,3.78,3.78]
# ]

# y_ctd_b = [
#     [1.02,2.81,2.95],
#     [1.42,2.38,2.75],
#     [1.76,3.02,3.70],
#     [2.52,4.15,4.36]
# ]

# csd
# y_ctd_s = [
#     [0.26,1.02,2.44],
#     [0.32,1.20,3.98],
#     [1.26,2.10,5.02],
#     [1.55,2.47,5.36]
# ]

# y_ctd_a = [
#     [3.53,4.61,9.23],
#     [3.89,5.48,9.75],
#     [6.26,6.89,10.39],
#     [6.95,7.24,11.21]
# ]

# y_ctd_t = [
#     [2.37,2.90,5.03],
#     [2.26,3.56,5.77],
#     [3.24,4.13,6.27],
#     [3.78,4.31,6.63]
# ]

# y_ctd_b = [
#     [1.74,2.58,4.35],
#     [1.99,3.29,5.28],
#     [2.94,3.78,5.95],
#     [4.45,5.10,6.80]
# ]

# bcbq
y_ctd_s = [
    [4.11,5.97,7.32],
    [4.09,6.18,7.12],
    [5.31,7.19,7.70],
    [5.66,7.59,8.18]
]

y_ctd_a = [
    [4.54,6.69,7.44],
    [4.47,6.70,7.38],
    [5.25,7.30,8.04],
    [6.01,7.80,8.41]
]

y_ctd_t = [
    [2.89,5.16,6.20],
    [3.02,5.32,6.40],
    [3.61,5.60,6.48],
    [4.07,6.19,6.87]
]

y_ctd_b = [
    [5.17,6.48,6.81],
    [5.16,6.47,6.82],
    [5.73,6.74,6.86],
    [6.57,7.09,7.09]
]

name = "BBC Dataset"

figure(figsize=(25, 6))

ax1 = plt.subplot(141)

ax1.plot(x, y_ctd_s[0], 'o-', label='None')
ax1.plot(x, y_ctd_s[1], 'o-', label='Synthesized-Midi')
ax1.plot(x, y_ctd_s[2], 'o-', label='Standard-Vocal')
ax1.plot(x, y_ctd_s[3], 'o-', label='Expressive-Vocal')
ax1.legend(prop={'size': 15})
ax1.set_xlabel("ratio", fontsize=20)
ax1.set_ylabel("Median SDR", fontsize=20)
ax1.tick_params(axis="x", labelsize=18)
ax1.tick_params(axis="y", labelsize=18)
ax1.set_title('Soprano-' + name,fontsize=25)

ax2 = plt.subplot(142)

ax2.plot(x, y_ctd_a[0], 'o-', label='None')
ax2.plot(x, y_ctd_a[1], 'o-', label='Synthesized-Midi')
ax2.plot(x, y_ctd_a[2], 'o-', label='Standard-Vocal')
ax2.plot(x, y_ctd_a[3], 'o-', label='Expressive-Vocal')
ax2.legend(prop={'size': 15})
ax2.set_xlabel("ratio", fontsize=20)
ax2.set_ylabel("Median SDR", fontsize=20)
ax2.tick_params(axis="x", labelsize=18)
ax2.tick_params(axis="y", labelsize=18)
ax2.set_title('Alto-' + name,fontsize=25)

ax3 = plt.subplot(143)

ax3.plot(x, y_ctd_t[0], 'o-', label='None')
ax3.plot(x, y_ctd_t[1], 'o-', label='Synthesized-Midi')
ax3.plot(x, y_ctd_t[2], 'o-', label='Standard-Vocal')
ax3.plot(x, y_ctd_t[3], 'o-', label='Expressive-Vocal')
ax3.legend(prop={'size': 15})
ax3.set_xlabel("ratio", fontsize=20)
ax3.set_ylabel("Median SDR", fontsize=20)
ax3.tick_params(axis="x", labelsize=18)
ax3.tick_params(axis="y", labelsize=18)
ax3.set_title('Tenor-' + name,fontsize=25)

ax4 = plt.subplot(144)

ax4.plot(x, y_ctd_b[0], 'o-', label='None')
ax4.plot(x, y_ctd_b[1], 'o-', label='Synthesized-Midi')
ax4.plot(x, y_ctd_b[2], 'o-', label='Standard-Vocal')
ax4.plot(x, y_ctd_b[3], 'o-', label='Expressive-Vocal')
ax4.legend(prop={'size': 15})
ax4.set_xlabel("ratio", fontsize=20)
ax4.set_ylabel("Median SDR", fontsize=20)
ax4.tick_params(axis="x", labelsize=18)
ax4.tick_params(axis="y", labelsize=18)
ax4.set_title('Bass-' + name,fontsize=25)


# plt.show()
plt.tight_layout()
# plt.show()
plt.savefig('../bbc-dataset-result.png', dpi = 600)

# %%
name = "BBC Dataset"
dips = 'o--'
x = np.array([0, 1,2])

def get_error(x, y):
    x = np.array(x)
    y = np.array(y)
    return [x-y[0], y[1]-x]

# ctd
# y_ctd_s = [
#     [2.60,7.28,7.63],
#     [5.14,7.55,7.57],
#     [6.51,7.94,8.25],
#     [6.85,8.87,9.41]
# ]

# y_ctd_a = [
#     [1.22,3.54,3.66],
#     [1.89,3.56,3.74],
#     [2.31,4.16,4.83],
#     [3.13,5.12,5.27]
# ]

# y_ctd_t = [
#     [0.54,2.28,2.35],
#     [0.45,2.09,2.13],
#     [1.00,3.24,3.54],
#     [2.01,3.78,3.81]
# ]

# y_ctd_b = [
#     [1.02,2.56,2.95],
#     [1.42,2.38,2.75],
#     [1.76,3.02,3.70],
#     [2.52,4.15,4.36]
# ]

# y_ctd_s_error = [
#     [[1.99, 5.77, 5.97], [2.95, 7.52, 7.71]],
#     [[3.44, 5.66, 5.83], [5.55, 7.97, 7.71]],
#     [[4.64, 5.97, 5.95], [6.75, 8.16, 8.45]],
#     [[5.16, 6.84, 7.20], [7.14, 9.36, 9.68]]
# ]


# y_ctd_a_error = [
#     [[0.83, 2.83, 2.94], [1.55, 3.81, 4.16]],
#     [[1.34, 2.69, 2.88], [2.34, 3.71, 4.01]],
#     [[1.80, 3.47, 3.88], [3.23, 4.63, 4.99]],
#     [[1.96, 4.06, 4.02], [4.09, 5.71, 5.90]]
# ]

# y_ctd_t_error = [
#     [[0.45, 1.52, 1.93], [0.81, 2.52, 2.35]],
#     [[0.02, 1.90, 1.61], [0.93, 2.15, 2.29]],
#     [[0.57, 2.85, 3.47], [1.62, 3.64, 3.59]],
#     [[1.59, 3.42, 3.50], [2.36, 3.83, 3.92]]
# ]

# y_ctd_b_error = [
#     [[0.98, 2.36, 2.53], [1.25, 2.77, 3.12]],
#     [[1.34, 2.35, 2.41], [1.47, 2.78, 3.01]],
#     [[1.49, 2.74, 3.09], [2.01, 3.45, 4.15]],
#     [[2.27, 3.79, 3.89], [3.15, 4.49, 4.59]]
# ]

#csd
# y_ctd_s = [
#     [0.26,1.02,2.44],
#     [0.32,1.20,3.98],
#     [1.26,2.10,5.02],
#     [1.55,2.47,5.36]
# ]

# y_ctd_a = [
#     [3.53,4.61,9.23],
#     [3.89,5.48,9.75],
#     [6.26,6.89,10.39],
#     [6.95,7.24,11.21]
# ]

# y_ctd_t = [
#     [2.37,2.90,5.03],
#     [2.26,3.56,5.77],
#     [3.24,4.13,6.27],
#     [3.78,4.31,6.63]
# ]

# y_ctd_b = [
#     [1.74,2.58,4.35],
#     [1.99,3.29,5.28],
#     [2.94,3.78,5.95],
#     [4.45,5.10,6.80]
# ]

# y_ctd_s_error = [
#     [[0.08, 0.82, 1.82], [0.53, 2.54, 3.17]],
#     [[0.04, 0.66, 3.03], [0.39, 2.90, 4.83]],
#     [[0.99, 1.48, 4.27], [1.47, 4.81, 5.89]],
#     [[1.11, 1.45, 4.60], [2.09, 5.14, 6.15]]
# ]

# y_ctd_a_error = [
#     [[2.79, 4.32, 6.35], [4.11, 8.12, 11.43]],
#     [[3.13, 5.05, 7.01], [4.17, 10.35, 11.97]],
#     [[5.66, 6.51, 7.53], [7.02, 11.19, 12.88]],
#     [[5.96, 6.30, 8.26], [7.33, 11.26, 13.99]]
# ]

# y_ctd_t_error = [
#     [[1.49, 2.23, 4.69], [2.41, 3.13, 5.41]],
#     [[1.49, 3.20, 5.56], [2.82, 4.97, 6.21]],
#     [[2.23, 3.37, 6.13], [3.98, 4.87, 6.61]],
#     [[2.65, 4.19, 6.33], [4.10, 4.92, 7.27]]
# ]

# y_ctd_b_error = [
#     [[1.43, 2.22, 4.12], [2.07, 3.60, 4.40]],
#     [[1.70, 2.92, 4.95], [2.24, 4.50, 5.34]],
#     [[2.64, 3.66, 5.49], [3.09, 4.94, 6.05]],
#     [[4.03, 4.64, 6.06], [4.67, 6.50, 7.46]]
# ]

# bbc 
y_ctd_s = [
    [4.11,5.97,7.32],
    [4.09,6.18,7.12],
    [5.31,7.19,7.70],
    [5.66,7.59,8.18]
]

y_ctd_a = [
    [4.54,6.69,7.44],
    [4.47,6.70,7.38],
    [5.25,7.30,8.04],
    [6.01,7.80,8.41]
]

y_ctd_t = [
    [2.89,5.16,6.20],
    [3.02,5.32,6.40],
    [3.61,5.60,6.48],
    [4.07,6.19,6.87]
]

y_ctd_b = [
    [5.17,6.48,6.81],
    [5.16,6.47,6.82],
    [5.73,6.74,6.86],
    [6.57,7.09,7.09]
]


y_ctd_s_error = [
    [[2.49, 4.31, 5.60], [5.59, 7.36, 8.37]],
    [[2.39, 4.18, 5.38], [5.98, 7.74, 8.81]],
    [[3.31, 5.35, 5.82], [7.14, 8.62, 9.05]],
    [[3.57, 5.56, 6.63], [7.77, 9.27, 9.46]]
]

y_ctd_a_error = [
    [[2.27, 4.38, 4.56], [7.67, 9.41, 10.61]],
    [[2.52, 4.46, 5.10], [6.73, 9.46, 10.41]],
    [[3.13, 4.90, 5.42], [7.98, 9.76, 10.89]],
    [[3.68, 5.42, 5.73], [8.62, 10.73, 11.28]]
]

y_ctd_t_error = [
    [[1.66, 3.79, 4.95], [2.99, 6.56, 7.58]],
    [[1.86, 4.10, 4.83], [4.35, 6.74, 7.35]],
    [[2.14, 4.19, 4.92], [5.09, 6.83, 7.71]],
    [[2.61, 4.60, 5.53], [5.51, 7.34, 7.93]]
]

y_ctd_b_error = [
    [[3.93, 5.27, 5.75], [6.90, 8.36, 8.31]],
    [[3.95, 5.32, 5.70], [6.57, 8.20, 8.37]],
    [[4.53, 5.56, 5.91], [7.37, 8.48, 8.68]],
    [[5.36, 5.86, 6.20], [8.08, 8.81, 9.01]]
]


figure(figsize=(25, 6))

ax1 = plt.subplot(141)

ax1.errorbar(x-0.12, y_ctd_s[0], yerr=get_error(y_ctd_s[0], y_ctd_s_error[0]), fmt=dips, label='None', capsize=10, capthick=2)
ax1.errorbar(x-0.06, y_ctd_s[1], yerr=get_error(y_ctd_s[1], y_ctd_s_error[1]), fmt=dips, label='Synthesized-Midi', capsize=10, capthick=2)
ax1.errorbar(x+0.06, y_ctd_s[2], yerr=get_error(y_ctd_s[2], y_ctd_s_error[2]), fmt=dips, label='Standard-Vocal', capsize=10, capthick=2)
ax1.errorbar(x+0.12, y_ctd_s[3], yerr=get_error(y_ctd_s[3], y_ctd_s_error[3]), fmt=dips, label='Expressive-Vocal', capsize=10, capthick=2)
ax1.set_xticks([0, 1, 2])
ax1.set_xticklabels(["10%", "40%", "70%"])
ax1.legend(prop={'size': 15})
ax1.set_xlabel("ratio", fontsize=20)
ax1.set_ylabel("Median SDR", fontsize=20)
ax1.tick_params(axis="x", labelsize=18)
ax1.tick_params(axis="y", labelsize=18)
ax1.set_title('Soprano-' + name,fontsize=25)

ax2 = plt.subplot(142)

ax2.errorbar(x-0.12, y_ctd_a[0], yerr=get_error(y_ctd_a[0], y_ctd_a_error[0]), fmt=dips, label='None', capsize=10, capthick=2)
ax2.errorbar(x-0.06, y_ctd_a[1], yerr=get_error(y_ctd_a[1], y_ctd_a_error[1]), fmt=dips, label='Synthesized-Midi', capsize=10, capthick=2)
ax2.errorbar(x+0.06, y_ctd_a[2], yerr=get_error(y_ctd_a[2], y_ctd_a_error[2]), fmt=dips, label='Standard-Vocal', capsize=10, capthick=2)
ax2.errorbar(x+0.12, y_ctd_a[3], yerr=get_error(y_ctd_a[3], y_ctd_a_error[3]), fmt=dips, label='Expressive-Vocal', capsize=10, capthick=2)
ax2.set_xticks([0, 1, 2])
ax2.set_xticklabels(["10%", "40%", "70%"])
ax2.legend(prop={'size': 15})
ax2.set_xlabel("ratio", fontsize=20)
ax2.set_ylabel("Median SDR", fontsize=20)
ax2.tick_params(axis="x", labelsize=18)
ax2.tick_params(axis="y", labelsize=18)
ax2.set_title('Alto-' + name,fontsize=25)

ax3 = plt.subplot(143)

ax3.errorbar(x-0.12, y_ctd_t[0], yerr=get_error(y_ctd_t[0], y_ctd_t_error[0]), fmt=dips, label='None', capsize=10, capthick=2)
ax3.errorbar(x-0.06, y_ctd_t[1], yerr=get_error(y_ctd_t[1], y_ctd_t_error[1]), fmt=dips, label='Synthesized-Midi', capsize=10, capthick=2)
ax3.errorbar(x+0.06, y_ctd_t[2], yerr=get_error(y_ctd_t[2], y_ctd_t_error[2]), fmt=dips, label='Standard-Vocal', capsize=10, capthick=2)
ax3.errorbar(x+0.12, y_ctd_t[3], yerr=get_error(y_ctd_t[3], y_ctd_t_error[3]), fmt=dips, label='Expressive-Vocal', capsize=10, capthick=2)
ax3.set_xticks([0, 1, 2])
ax3.set_xticklabels(["10%", "40%", "70%"])
ax3.legend(prop={'size': 15})
ax3.set_xlabel("ratio", fontsize=20)
ax3.set_ylabel("Median SDR", fontsize=20)
ax3.tick_params(axis="x", labelsize=18)
ax3.tick_params(axis="y", labelsize=18)
ax3.set_title('Tenor-' + name,fontsize=25)

ax4 = plt.subplot(144)

ax4.errorbar(x-0.12, y_ctd_b[0], yerr=get_error(y_ctd_b[0], y_ctd_b_error[0]), fmt=dips, label='None', capsize=10, capthick=2)
ax4.errorbar(x-0.06, y_ctd_b[1], yerr=get_error(y_ctd_b[1], y_ctd_b_error[1]), fmt=dips, label='Synthesized-Midi', capsize=10, capthick=2)
ax4.errorbar(x+0.06, y_ctd_b[2], yerr=get_error(y_ctd_b[2], y_ctd_b_error[2]), fmt=dips, label='Standard-Vocal', capsize=10, capthick=2)
ax4.errorbar(x+0.12, y_ctd_b[3], yerr=get_error(y_ctd_b[3], y_ctd_b_error[3]), fmt=dips, label='Expressive-Vocal', capsize=10, capthick=2)
ax4.set_xticks([0, 1, 2])
ax4.set_xticklabels(["10%", "40%", "70%"])
ax4.legend(prop={'size': 15})
ax4.set_xlabel("ratio", fontsize=20)
ax4.set_ylabel("Median SDR", fontsize=20)
ax4.tick_params(axis="x", labelsize=18)
ax4.tick_params(axis="y", labelsize=18)
ax4.set_title('Bass-' + name,fontsize=25)




plt.tight_layout()
plt.savefig('../bbc-dataset-result.png', dpi = 300)
